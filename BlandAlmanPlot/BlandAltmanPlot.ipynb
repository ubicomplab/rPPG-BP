# %%
import pandas as pd
import numpy as np
import BlandAltmanPy

# %% [markdown]
# ## Window size of 10

# %%
# Load example data file:
window_size = 10
face_hr = np.load(f'../results/face_hr_all_ws_{window_size}.npy')
ecg_hr = np.load(f'../results/ecg_hr_all_ws_{window_size}.npy')
print('face hr. shape: ', face_hr.shape)
print('ecg hr. shape: ', ecg_hr.shape)
compare = BlandAltmanPy.BlandAltman(ecg_hr,face_hr,averaged=True)
compare.scatter_plot(x_label='ECG HR [bpm]',y_label='Face PPG HR [bpm]', figure_size=(5, 5), file_name=f'ScatterPlot{window_size}.pdf')
compare.difference_plot(figure_size=(5, 5), file_name=f'BlandAltman{window_size}.pdf')
compare.print_stats(round_amount = 3)
# Out:
# face hr. shape:  (1584,)
# ecg hr. shape:  (1584,)
# Mean error = 0.101
# Mean absolute error = 3.139
# Mean squared error = 32.499
# Root mean squared error = 5.701
# Correlation = 0.857
# +95% Confidence Interval = 15.905
# -95% Confidence Interval = -15.704

# %% [markdown]
# ## Window size of 15

# %%
# Load example data file:
window_size = 15
face_hr = np.load(f'../results/face_hr_all_ws_{window_size}.npy')
ecg_hr = np.load(f'../results/ecg_hr_all_ws_{window_size}.npy')
print('face hr. shape: ', face_hr.shape)
print('ecg hr. shape: ', ecg_hr.shape)
compare = BlandAltmanPy.BlandAltman(ecg_hr,face_hr,averaged=True)
compare.scatter_plot(x_label='ECG HR [bpm]',y_label='Face PPG HR [bpm]', figure_size=(5, 5), file_name=f'ScatterPlot{window_size}.pdf')
compare.difference_plot(figure_size=(5, 5), file_name=f'BlandAltman{window_size}.pdf')
compare.print_stats(round_amount = 3)
# Out:
# face hr. shape:  (1056,)
# ecg hr. shape:  (1056,)
# Mean error = 0.185
# Mean absolute error = 2.843
# Mean squared error = 27.38
# Root mean squared error = 5.233
# Correlation = 0.876
# +95% Confidence Interval = 14.687
# -95% Confidence Interval = -14.317

# %% [markdown]
# ## Window size of 30

# %%
# Load example data file:
window_size = 30
face_hr = np.load(f'../results/face_hr_all_ws_{window_size}.npy')
ecg_hr = np.load(f'../results/ecg_hr_all_ws_{window_size}.npy')
print('face hr. shape: ', face_hr.shape)
print('ecg hr. shape: ', ecg_hr.shape)
compare = BlandAltmanPy.BlandAltman(ecg_hr,face_hr,averaged=True)
compare.scatter_plot(x_label='ECG HR [bpm]',y_label='Face PPG HR [bpm]', figure_size=(5, 5), file_name=f'ScatterPlot{window_size}.pdf')
compare.difference_plot(figure_size=(5, 5), file_name=f'BlandAltman{window_size}.pdf')
compare.print_stats(round_amount = 3)
# Out:
# face hr. shape:  (528,)
# ecg hr. shape:  (528,)
# Mean error = -0.076
# Mean absolute error = 2.07
# Mean squared error = 18.755
# Root mean squared error = 4.331
# Correlation = 0.915
# +95% Confidence Interval = 11.937
# -95% Confidence Interval = -12.09

# %% [markdown]
# ## Window size of 60

# %%
# Load example data file:
window_size = 60
face_hr = np.load(f'../results/face_hr_all_ws_{window_size}.npy')
ecg_hr = np.load(f'../results/ecg_hr_all_ws_{window_size}.npy')
print('face hr. shape: ', face_hr.shape)
print('ecg hr. shape: ', ecg_hr.shape)
compare = BlandAltmanPy.BlandAltman(ecg_hr,face_hr,averaged=True)
compare.scatter_plot(x_label='ECG HR [bpm]',y_label='Face PPG HR [bpm]', figure_size=(5, 5), file_name=f'ScatterPlot{window_size}.pdf')
compare.difference_plot(figure_size=(5, 5), file_name=f'BlandAltman{window_size}.pdf')
compare.print_stats(round_amount = 3)
# Out:
# face hr. shape:  (264,)
# ecg hr. shape:  (264,)
# Mean error = 0.036
# Mean absolute error = 1.483
# Mean squared error = 7.936
# Root mean squared error = 2.817
# Correlation = 0.964
# +95% Confidence Interval = 7.858
# -95% Confidence Interval = -7.787
