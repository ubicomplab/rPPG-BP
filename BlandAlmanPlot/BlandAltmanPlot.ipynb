# %%
import pandas as pd
import numpy as np
import BlandAltmanPy
from matplotlib import pyplot as plt

# %% [markdown]
# ## Window size of 5

# %%
# Load example data file:
window_size = 5
finger_hr = np.load(f'../finger_hr_all_ws_{window_size}.npy')
face_hr = np.load(f'../face_hr_all_ws_{window_size}.npy')
compare = BlandAltmanPy.BlandAltman(finger_hr,face_hr,averaged=True)
compare.scatter_plot(x_label='Finger PPG HR [bpm]',y_label='Face PPG HR [bpm]')
compare.difference_plot()
compare.print_stats(round_amount = 3)
# Out:
# Mean error = 0.054
# Mean absolute error = 9.254
# Mean squared error = 260.284
# Root mean squared error = 16.133
# Correlation = nan
# +95% Confidence Interval = 44.78
# -95% Confidence Interval = -44.673

# %% [markdown]
# ## Window size of 10

# %%
# Load example data file:
window_size = 10
finger_hr = np.load(f'../finger_hr_all_ws_{window_size}.npy')
face_hr = np.load(f'../face_hr_all_ws_{window_size}.npy')
compare = BlandAltmanPy.BlandAltman(finger_hr,face_hr,averaged=True)
compare.scatter_plot(x_label='Finger PPG HR [bpm]',y_label='Face PPG HR [bpm]')
compare.difference_plot()
compare.print_stats(round_amount = 3)
# Out:
# Mean error = -0.023
# Mean absolute error = 8.194
# Mean squared error = 213.592
# Root mean squared error = 14.615
# Correlation = nan
# +95% Confidence Interval = 40.501
# -95% Confidence Interval = -40.547

# %% [markdown]
# ## Window size of 30

# %%
# Load example data file:
window_size = 30
finger_hr = np.load(f'../finger_hr_all_ws_{window_size}.npy')
face_hr = np.load(f'../face_hr_all_ws_{window_size}.npy')
compare = BlandAltmanPy.BlandAltman(finger_hr,face_hr,averaged=True)
compare.scatter_plot(x_label='Finger PPG HR [bpm]',y_label='Face PPG HR [bpm]')
compare.difference_plot()
compare.print_stats(round_amount = 3)
# Out:
# Mean error = -0.545
# Mean absolute error = 7.944
# Mean squared error = 221.795
# Root mean squared error = 14.893
# Correlation = 0.372
# +95% Confidence Interval = 40.76
# -95% Confidence Interval = -41.85

# %% [markdown]
# ## Window size of 60

# %%
# Load example data file:
window_size = 60
finger_hr = np.load(f'../finger_hr_all_ws_{window_size}.npy')
face_hr = np.load(f'../face_hr_all_ws_{window_size}.npy')
compare = BlandAltmanPy.BlandAltman(finger_hr,face_hr,averaged=True)
compare.scatter_plot(x_label='Finger PPG HR [bpm]',y_label='Face PPG HR [bpm]')
compare.difference_plot()
compare.print_stats(round_amount = 3)
# Out:
# Mean error = -0.861
# Mean absolute error = 7.43
# Mean squared error = 204.669
# Root mean squared error = 14.306
# Correlation = 0.396
# +95% Confidence Interval = 38.871
# -95% Confidence Interval = -40.594

# %% [markdown]
# ## Window size of 90

# %%
# Load example data file:
window_size = 90
finger_hr = np.load(f'../finger_hr_all_ws_{window_size}.npy')
face_hr = np.load(f'../face_hr_all_ws_{window_size}.npy')
compare = BlandAltmanPy.BlandAltman(finger_hr,face_hr,averaged=True)
compare.scatter_plot(x_label='Finger PPG HR [bpm]',y_label='Face PPG HR [bpm]')
compare.difference_plot()
compare.print_stats(round_amount = 3)
# Out:
# Mean error = -0.951
# Mean absolute error = 7.05
# Mean squared error = 186.066
# Root mean squared error = 13.641
# Correlation = 0.419
# +95% Confidence Interval = 36.912
# -95% Confidence Interval = -38.813
