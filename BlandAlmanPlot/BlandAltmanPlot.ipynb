# %%
import pandas as pd
import numpy as np
import BlandAltmanPy

# %% [markdown]
# ## Window size of 10

# %%
# Load example data file:
window_size = 10
finger_hr = np.load(f'../results/finger_hr_all_ws_{window_size}.npy')
face_hr = np.load(f'../results/face_hr_all_ws_{window_size}.npy')
compare = BlandAltmanPy.BlandAltman(finger_hr,face_hr,averaged=True)
compare.scatter_plot(x_label='Finger PPG HR [bpm]',y_label='Face PPG HR [bpm]')
compare.difference_plot()
compare.print_stats(round_amount = 3)
# Out:
# Mean error = -0.709
# Mean absolute error = 3.337
# Mean squared error = 45.49
# Root mean squared error = 6.745
# Correlation = 0.8
# +95% Confidence Interval = 17.889
# -95% Confidence Interval = -19.307

# %% [markdown]
# ## Window size of 15

# %%
# Load example data file:
window_size = 15
finger_hr = np.load(f'../results/finger_hr_all_ws_{window_size}.npy')
face_hr = np.load(f'../results/face_hr_all_ws_{window_size}.npy')
compare = BlandAltmanPy.BlandAltman(finger_hr,face_hr,averaged=True)
compare.scatter_plot(x_label='Finger PPG HR [bpm]',y_label='Face PPG HR [bpm]')
compare.difference_plot()
compare.print_stats(round_amount = 3)
# Out:
# Mean error = -0.38
# Mean absolute error = 2.731
# Mean squared error = 30.396
# Root mean squared error = 5.513
# Correlation = 0.862
# +95% Confidence Interval = 14.873
# -95% Confidence Interval = -15.633

# %% [markdown]
# ## Window size of 30

# %%
# Load example data file:
window_size = 30
finger_hr = np.load(f'../results/finger_hr_all_ws_{window_size}.npy')
face_hr = np.load(f'../results/face_hr_all_ws_{window_size}.npy')
compare = BlandAltmanPy.BlandAltman(finger_hr,face_hr,averaged=True)
compare.scatter_plot(x_label='Finger PPG HR [bpm]',y_label='Face PPG HR [bpm]')
compare.difference_plot()
compare.print_stats(round_amount = 3)
# Out:
# Mean error = -0.582
# Mean absolute error = 2.096
# Mean squared error = 20.691
# Root mean squared error = 4.549
# Correlation = 0.904
# +95% Confidence Interval = 11.935
# -95% Confidence Interval = -13.1

# %% [markdown]
# ## Window size of 60

# %%
# Load example data file:
window_size = 60
finger_hr = np.load(f'../results/finger_hr_all_ws_{window_size}.npy')
face_hr = np.load(f'../results/face_hr_all_ws_{window_size}.npy')
compare = BlandAltmanPy.BlandAltman(finger_hr,face_hr,averaged=True)
compare.scatter_plot(x_label='Finger PPG HR [bpm]',y_label='Face PPG HR [bpm]')
compare.difference_plot()
compare.print_stats(round_amount = 3)
# Out:
# Mean error = -0.509
# Mean absolute error = 1.751
# Mean squared error = 19.79
# Root mean squared error = 4.449
# Correlation = 0.907
# +95% Confidence Interval = 11.765
# -95% Confidence Interval = -12.783

# %% [markdown]
# ## Window size of 90

# %%
# Load example data file:
window_size = 90
finger_hr = np.load(f'../results/finger_hr_all_ws_{window_size}.npy')
face_hr = np.load(f'../results/face_hr_all_ws_{window_size}.npy')
compare = BlandAltmanPy.BlandAltman(finger_hr,face_hr,averaged=True)
compare.scatter_plot(x_label='Finger PPG HR [bpm]',y_label='Face PPG HR [bpm]')
compare.difference_plot()
compare.print_stats(round_amount = 3)
# Out:
# Mean error = -0.513
# Mean absolute error = 1.681
# Mean squared error = 17.275
# Root mean squared error = 4.156
# Correlation = 0.92
# +95% Confidence Interval = 10.943
# -95% Confidence Interval = -11.968
